# %%
# %cd ..
# Out:
# /home/marysia/Documents/GitHub/MRI_machine_learning

# %%
import pandas as pd
from utils import plots

# %%
#reaload plots
from importlib import reload
reload(plots)
# Out:
# <module 'utils.plots' from '/home/marysia/Documents/GitHub/MRI_machine_learning/utils/plots.py'>

# %%
data_type='positive'
results_svm=pd.read_csv(f'results/test_{data_type}_regression_results_svm_valid_0.csv', sep='\t')
plots.age_prediction_function(results_svm, model="SVM", data_type=data_type, valid=False, language='pl')

results_svm=pd.read_csv(f'results/test_{data_type}_regression_results_svm_valid_1.csv', sep='\t')
plots.age_prediction_function(results_svm, model="SVM", data_type=data_type, valid=True, language='pl')
# Out:
# /home/marysia/Documents/GitHub/MRI_machine_learning/utils/plots.py:276: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b--" (-> color='b'). The keyword argument will take precedence.
# /home/marysia/Documents/GitHub/MRI_machine_learning/utils/plots.py:276: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b--" (-> color='b'). The keyword argument will take precedence.

# %%
results_svm=pd.read_csv(f'results/train_{data_type}_test_None_regression_results_svm_valid_0.csv', sep='\t')
plots.age_prediction_gap(results_svm, model="SVM", data_type=data_type, valid=False, language='pl')


results_svm=pd.read_csv(f'results/train_{data_type}_test_None_regression_results_svm_valid_1.csv', sep='\t')
plots.age_prediction_gap(results_svm, model="SVM", data_type=data_type, valid=True, language='pl')
